# %%
from dataset_builder_for_segmentation import build_pipeline

# %%
#input_image_dir : (str) local directory containing input images
#output_image_dir : (str)local directory containing ground truth output images
#batch_sz : (int) batch size
#repeat_shuffle : (boolean) option to repeat shuffling for multiple epochs


dataset = build_pipeline(input_image_dir = 'C:\\Segmentation_Data\\input',
                         output_image_dir = 'C:\\Segmentation_Data\\output',
                         batch_sz = 3,
                         repeat_shuffle = True)
# Out:
#  BUILDING DATASET ...
#
# Enter input image size as <rows>,<columns> for your model:
# 96,128
# Enter output image size as <rows>,<columns> for your model:
# 96,128
#
#  SAMPLE INPUT-GROUND TRUTH OUPUT PAIR:
#  DATASET READY AND RETURNED
